# %%
import pandas as pd
import os
import numpy as np
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

root_path = os.path.dirname((os.getcwd()))

# %%
data_path = os.path.join(Path(os.getcwd()).resolve().parents[1], "dataset.xlsx")
df = pd.read_excel(data_path)

# %%
df.head(3)
# Out:
#      studentID               classID                   timeStamp  \
# 0  student_001  GENE1001-2-3-24(N01)  2025-08-18 04:11:05.921000
# 1  student_001  GENE1001-2-3-24(N01)  2025-08-18 04:11:43.762000
# 2  student_001  GENE1001-2-3-24(N01)  2025-08-18 04:11:43.808000
#
#   studentEmotion  finalScore  totalImages  learningTimes  finishedLession  \
# 0        neutral        10.0          263            214               87
# 1        neutral        10.0          263            214               87
# 2        neutral        10.0          263            214               87
#
#    avgTimeLearn  avgTimeFinish  percentageFinish  timeInWeek  inTime  outTime  \
# 0          12.7           31.2              49.1      2714.7  2033.4    681.3
# 1          12.7           31.2              49.1      2714.7  2033.4    681.3
# 2          12.7           31.2              49.1      2714.7  2033.4    681.3
#
#    inWeekday  outWeekday
# 0     2589.2       125.5
# 1     2589.2       125.5
# 2     2589.2       125.5

# %%
df.describe()
# Out:
#          finalScore   totalImages  learningTimes  finishedLession  \
# count  12095.000000  12095.000000   12095.000000     12095.000000
# mean       8.140814    175.323522      99.201323        44.500124
# std        2.088232    117.693367      63.929325        21.251072
# min        0.000000      3.000000       1.000000         0.000000
# 25%        7.600000     82.000000      45.000000        26.000000
# 50%        8.400000    140.000000      75.000000        36.000000
# 75%        9.250000    251.000000     155.000000        66.000000
# max       10.000000    524.000000     257.000000        87.000000
#
#        avgTimeLearn  avgTimeFinish  percentageFinish    timeInWeek  \
# count  12095.000000   12095.000000      12095.000000  12095.000000
# mean      10.050508      19.171277         60.005539    924.517983
# std       16.710562      29.906770         16.612644   1408.891266
# min        0.200000       0.000000          0.000000      0.200000
# 25%        4.500000      10.900000         48.100000    308.100000
# 50%        7.100000      13.600000         59.900000    475.400000
# 75%        9.400000      17.100000         72.800000    865.100000
# max      155.700000     346.800000        100.000000  10628.200000
#
#              inTime       outTime     inWeekday    outWeekday
# count  12095.000000  12095.000000  12095.000000  12095.000000
# mean     562.206507    362.311476    681.091848    243.426135
# std      894.763634    940.605427   1348.985372    397.342973
# min        0.200000      0.000000      0.000000      0.000000
# 25%      180.300000     96.000000    204.200000     29.500000
# 50%      283.800000    169.800000    317.000000    125.500000
# 75%      550.600000    311.700000    551.000000    302.900000
# max     8539.900000   9972.500000  10628.200000   2630.700000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12095 entries, 0 to 12094
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   studentID         12095 non-null  object
#  1   classID           12095 non-null  object
#  2   timeStamp         12095 non-null  object
#  3   studentEmotion    12095 non-null  object
#  4   finalScore        12095 non-null  float64
#  5   totalImages       12095 non-null  int64
#  6   learningTimes     12095 non-null  int64
#  7   finishedLession   12095 non-null  int64
#  8   avgTimeLearn      12095 non-null  float64
#  9   avgTimeFinish     12095 non-null  float64
#  10  percentageFinish  12095 non-null  float64
#  11  timeInWeek        12095 non-null  float64
#  12  inTime            12095 non-null  float64
#  13  outTime           12095 non-null  float64
#  14  inWeekday         12095 non-null  float64
#  15  outWeekday        12095 non-null  float64
# dtypes: float64(9), int64(3), object(4)
# memory usage: 1.5+ MB

# %%
df = df.drop_duplicates(subset=["studentID"])

# %%
def encode_emotion(df, emotion_col, id_col="studentID"):
    encoding_map = {
        "neutral": 0,
        "happy": 1,
        "sad": -1
    }

    df = df.copy()
    df[emotion_col + "_encoded"] = df[emotion_col].map(encoding_map)

    result = (
        df.groupby(id_col)[emotion_col + "_encoded"]
          .sum()
          .reset_index(name="emotion_sum")
    )

    return result

# %%
def log_transform(df, columns, eps=1e-6):
    df = df.copy()
    
    for col in columns:
        df[col] = np.log1p(np.clip(df[col], -1 + eps, None))
    
    return df

# %%
def z_score_transform(df, id_col):
    df = df.copy()
    cols_to_scale = df.columns.difference([id_col])
    scaler = StandardScaler()
    df.loc[:, cols_to_scale] = scaler.fit_transform(df[cols_to_scale])
    return df

def scale_transform(df, column):
    df = df.copy()
    scaler = MinMaxScaler(feature_range=(0, 10))
    df[column + "_scaled"] = scaler.fit_transform(df[[column]])
    df = df.drop([column], axis=1)
    return df

# %%
master_df = encode_emotion(df, emotion_col='studentEmotion', id_col='studentID')
master_df = master_df.merge(df, how="inner", on="studentID")
master_df = master_df.drop(["classID", "timeStamp","studentEmotion", "timeInWeek"], axis=1)

# %%
print(master_df.shape)
master_df
# Out:
# (169, 13)
#        studentID  emotion_sum  finalScore  totalImages  learningTimes  \
# 0    student_001            0       10.00          263            214
# 1    student_002            0        7.60          259            161
# 2    student_003           -1        8.40          395            217
# 3    student_004            0        8.00          203            131
# 4    student_005           -1        6.00          280            136
# ..           ...          ...         ...          ...            ...
# 164  student_165            0        9.75           41             27
# 165  student_166            0        0.00            3              1
# 166  student_167           -1        8.25           17             53
# 167  student_168            0        9.50          176             95
# 168  student_169            0        9.75           46             26
#
#      finishedLession  avgTimeLearn  avgTimeFinish  percentageFinish  inTime  \
# 0                 87          12.7           31.2              49.1  2033.4
# 1                 67           9.0           21.6              49.6  1138.8
# 2                 82           8.0           21.2              43.2   702.4
# 3                 61          21.4           46.0              53.1   455.2
# 4                 64           8.1           17.3              51.5   275.6
# ..               ...           ...            ...               ...     ...
# 164               20          19.3           26.0              76.1   392.5
# 165                0           0.2            0.0               0.0     0.2
# 166               21           6.7           16.9              49.4   274.8
# 167               25           3.5           13.1              35.5   167.8
# 168               20          10.3           13.4              85.3   135.0
#
#      outTime  inWeekday  outWeekday
# 0      681.3     2589.2       125.5
# 1      311.7     1229.4       221.1
# 2     1038.2     1404.2       336.4
# 3     2349.2     1827.3       977.1
# 4      828.7      959.1       145.2
# ..       ...        ...         ...
# 164    127.6      330.9       189.2
# 165      0.0        0.0         0.2
# 166     80.0      224.0       130.8
# 167    160.4       44.3       283.9
# 168    133.7      170.8        97.9
#
# [169 rows x 13 columns]

# %%
master_df.describe()
# Out:
#        emotion_sum  finalScore  totalImages  learningTimes  finishedLession  \
# count   169.000000  169.000000   169.000000     169.000000       169.000000
# mean     -0.295858    8.295858   121.538462      72.307692        36.686391
# std       0.552091    2.264605   100.922884      54.395269        19.207882
# min      -1.000000    0.000000     3.000000       1.000000         0.000000
# 25%      -1.000000    8.000000    52.000000      37.000000        22.000000
# 50%       0.000000    9.000000    94.000000      53.000000        30.000000
# 75%       0.000000    9.500000   154.000000      84.000000        44.000000
# max       1.000000   10.000000   524.000000     257.000000        87.000000
#
#        avgTimeLearn  avgTimeFinish  percentageFinish       inTime  \
# count    169.000000     169.000000        169.000000   169.000000
# mean      11.679290      20.433136         66.854438   451.417751
# std       18.731155      35.646655         17.963925   870.887167
# min        0.200000       0.000000          0.000000     0.200000
# 25%        5.400000      11.200000         53.900000   160.900000
# 50%        8.100000      13.600000         67.400000   240.200000
# 75%       12.100000      16.600000         79.800000   392.500000
# max      155.700000     346.800000        100.000000  8539.900000
#
#            outTime     inWeekday   outWeekday
# count   169.000000    169.000000   169.000000
# mean    378.068639    658.799408   170.686982
# std    1103.360594   1490.812950   291.358533
# min       0.000000      0.000000     0.000000
# 25%      83.200000    201.600000     8.600000
# 50%     154.100000    283.900000    89.800000
# 75%     266.700000    445.900000   195.200000
# max    9972.500000  10628.200000  2630.700000

# %%
log_cols = master_df.drop(["studentID", "finalScore"], axis=1).columns
emotion_scale = scale_transform(df=master_df[["studentID", "emotion_sum"]], column="emotion_sum")

# %%
master_df.head(5)
# Out:
#      studentID  emotion_sum  finalScore  totalImages  learningTimes  \
# 0  student_001            0        10.0          263            214
# 1  student_002            0         7.6          259            161
# 2  student_003           -1         8.4          395            217
# 3  student_004            0         8.0          203            131
# 4  student_005           -1         6.0          280            136
#
#    finishedLession  avgTimeLearn  avgTimeFinish  percentageFinish  inTime  \
# 0               87          12.7           31.2              49.1  2033.4
# 1               67           9.0           21.6              49.6  1138.8
# 2               82           8.0           21.2              43.2   702.4
# 3               61          21.4           46.0              53.1   455.2
# 4               64           8.1           17.3              51.5   275.6
#
#    outTime  inWeekday  outWeekday
# 0    681.3     2589.2       125.5
# 1    311.7     1229.4       221.1
# 2   1038.2     1404.2       336.4
# 3   2349.2     1827.3       977.1
# 4    828.7      959.1       145.2

# %%
log_cols
# Out:
# Index(['emotion_sum', 'totalImages', 'learningTimes', 'finishedLession',
#        'avgTimeLearn', 'avgTimeFinish', 'percentageFinish', 'inTime',
#        'outTime', 'inWeekday', 'outWeekday'],
#       dtype='object')

# %%
log_transform(df=master_df, columns=log_cols)
# Out:
#        studentID  emotion_sum  finalScore  totalImages  learningTimes  \
# 0    student_001     0.000000       10.00     5.575949       5.370638
# 1    student_002     0.000000        7.60     5.560682       5.087596
# 2    student_003   -13.815511        8.40     5.981414       5.384495
# 3    student_004     0.000000        8.00     5.318120       4.882802
# 4    student_005   -13.815511        6.00     5.638355       4.919981
# ..           ...          ...         ...          ...            ...
# 164  student_165     0.000000        9.75     3.737670       3.332205
# 165  student_166     0.000000        0.00     1.386294       0.693147
# 166  student_167   -13.815511        8.25     2.890372       3.988984
# 167  student_168     0.000000        9.50     5.176150       4.564348
# 168  student_169     0.000000        9.75     3.850148       3.295837
#
#      finishedLession  avgTimeLearn  avgTimeFinish  percentageFinish    inTime  \
# 0           4.477337      2.617396       3.471966          3.914021  7.617956
# 1           4.219508      2.302585       3.117950          3.923952  7.038608
# 2           4.418841      2.197225       3.100092          3.788725  6.555926
# 3           4.127134      3.109061       3.850148          3.990834  6.122931
# 4           4.174387      2.208274       2.906901          3.960813  5.622572
# ..               ...           ...            ...               ...       ...
# 164         3.044522      3.010621       3.295837          4.345103  5.975081
# 165         0.000000      0.182322       0.000000          0.000000  0.182322
# 166         3.091042      2.041220       2.884801          3.919991  5.619676
# 167         3.258097      1.504077       2.646175          3.597312  5.128715
# 168         3.044522      2.424803       2.667228          4.457830  4.912655
#
#       outTime  inWeekday  outWeekday
# 0    6.525469   7.859490    4.840242
# 1    5.745244   7.115095    5.403128
# 2    6.946206   7.247935    5.821269
# 3    7.762256   7.511142    6.885612
# 4    6.721064   6.867037    4.984976
# ..        ...        ...         ...
# 164  4.856707   5.804834    5.248076
# 165  0.000000   0.000000    0.182322
# 166  4.394449   5.416100    4.881286
# 167  5.083886   3.813307    5.652138
# 168  4.903050   5.146331    4.594109
#
# [169 rows x 13 columns]

# %%
df_transformed = log_transform(df=master_df, columns=log_cols)
df_transformed = df_transformed.merge(emotion_scale, how="inner", on="studentID")
df_transformed = df_transformed.drop(["emotion_sum"], axis=1)
df_transformed = z_score_transform(df=df_transformed, id_col="studentID")

# %%
print(df_transformed.shape)
df_transformed.head(3)
# Out:
# (169, 13)
#      studentID  finalScore  totalImages  learningTimes  finishedLession  \
# 0  student_001    0.754748     1.293228       1.905885         1.819326
# 1  student_002   -0.308189     1.274963       1.493427         1.338519
# 2  student_003    0.046123     1.778293       1.926077         1.710241
#
#    avgTimeLearn  avgTimeFinish  percentageFinish    inTime   outTime  \
# 0      0.587077       1.155823         -0.579566  1.855016  1.125628
# 1      0.096610       0.590586         -0.556346  1.357795  0.574302
# 2     -0.067539       0.562073         -0.872532  0.943537  1.422931
#
#    inWeekday  outWeekday  emotion_sum_scaled
# 0   1.979479    0.497655            0.537479
# 1   1.279082    0.750887            0.537479
# 2   1.404071    0.939002           -1.279200

# %%
df_transformed.describe()
# Out:
#          finalScore   totalImages  learningTimes  finishedLession  \
# count  1.690000e+02  1.690000e+02   1.690000e+02     1.690000e+02
# mean  -1.051099e-16  7.147471e-16  -8.408790e-17    -7.988350e-16
# std    1.002972e+00  1.002972e+00   1.002972e+00     1.002972e+00
# min   -3.674156e+00 -3.718933e+00  -4.910302e+00    -6.530132e+00
# 25%   -1.310327e-01 -6.276492e-01  -6.195730e-01    -6.829783e-01
# 50%    3.118577e-01  7.050421e-02  -1.075050e-01    -1.263405e-01
# 75%    5.333030e-01  6.561597e-01   5.535931e-01     5.686344e-01
# max    7.547482e-01  2.115636e+00   2.171569e+00     1.819326e+00
#
#        avgTimeLearn  avgTimeFinish  percentageFinish        inTime  \
# count  1.690000e+02   1.690000e+02      1.690000e+02  1.690000e+02
# mean   2.732857e-16  -5.255494e-16     -1.828912e-15 -7.567911e-16
# std    1.002972e+00   1.002972e+00      1.002972e+00  1.002972e+00
# min   -3.206703e+00  -4.387660e+00     -9.731275e+00 -4.526555e+00
# 25%   -5.986931e-01  -3.937658e-01     -3.656398e-01 -3.171743e-01
# 50%   -5.032335e-02  -1.070321e-01      1.484325e-01  2.496164e-02
# 75%    5.173051e-01   1.913439e-01      5.379840e-01  4.450319e-01
# max    4.383759e+00   4.955287e+00      1.059735e+00  3.086305e+00
#
#             outTime     inWeekday    outWeekday  emotion_sum_scaled
# count  1.690000e+02  1.690000e+02  1.690000e+02        1.690000e+02
# mean   2.732857e-16  1.681758e-16 -2.312417e-16        6.569367e-18
# std    1.002972e+00  1.002972e+00  1.002972e+00        1.002972e+00
# min   -3.485426e+00 -5.415461e+00 -1.679883e+00       -1.279200e+00
# 25%   -3.528237e-01 -4.181579e-01 -6.623566e-01       -1.279200e+00
# 50%    7.883539e-02 -9.740312e-02  3.484819e-01        5.374791e-01
# 75%    4.645086e-01  3.261838e-01  6.951050e-01        5.374791e-01
# max    3.020947e+00  3.307898e+00  1.863112e+00        2.354158e+00

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
target_col = "finalScore"
X = df_transformed.drop(columns=["studentID", "finalScore"], axis=1)
y = df_transformed[target_col]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=52
)

# %%
model = AdaBoostRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
def eval_reg(y_true, y_pred, name=""):
    print(f"\n{name}")
    print("MSE:", mean_squared_error(y_true, y_pred))
    print("MAE:", mean_absolute_error(y_true, y_pred))
    print("R2 :", r2_score(y_true, y_pred))

eval_reg(y_test, model.predict(X_test), "Test")
# Out:
# Test
# MSE: 1.0099003908358963
# MAE: 0.5278289488710517
# R2 : 0.26957212264691577
